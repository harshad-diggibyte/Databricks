# %%
#Create Sample Dataframe
empDF = [('John',[4, 6, 7, 9, 2],[1, 2, 3, 7, 7]),
         ('David',[5, 1, 4, 7,1],[3, 2, 8, 9, 4, 9]),
         ('Mike', [6, 9, 1, 8, 2],[1, 2, 3, 5, 8])
        ]

df = spark.createDataFrame(data=empDF, schema = ['Name','Array_1','Array_2'])
df.show()
# Out:
# +-----+---------------+------------------+
# | Name|        Array_1|           Array_2|
# +-----+---------------+------------------+
# | John|[4, 6, 7, 9, 2]|   [1, 2, 3, 7, 7]|
# |David|[5, 1, 4, 7, 1]|[3, 2, 8, 9, 4, 9]|
# | Mike|[6, 9, 1, 8, 2]|   [1, 2, 3, 5, 8]|
# +-----+---------------+------------------+

# %%
#Apply Array_intersect
from pyspark.sql import functions as F

df_intersect= df.withColumn("Intersect",F.array_except(df["Array_1"],df["Array_2"]))
df_intersect.show()
# Out:
# +-----+---------------+------------------+---------+
# | Name|        Array_1|           Array_2|Intersect|
# +-----+---------------+------------------+---------+
# | John|[4, 6, 7, 9, 2]|   [1, 2, 3, 7, 7]|[4, 6, 9]|
# |David|[5, 1, 4, 7, 1]|[3, 2, 8, 9, 4, 9]|[5, 1, 7]|
# | Mike|[6, 9, 1, 8, 2]|   [1, 2, 3, 5, 8]|   [6, 9]|
# +-----+---------------+------------------+---------+

# %%
from pyspark.sql import functions as F

df_intersect= df.withColumn("Intersect",F.array_except(df["Array_2"],df["Array_1"]))
df_intersect.show()
# Out:
# +-----+---------------+------------------+------------+
# | Name|        Array_1|           Array_2|   Intersect|
# +-----+---------------+------------------+------------+
# | John|[4, 6, 7, 9, 2]|   [1, 2, 3, 7, 7]|      [1, 3]|
# |David|[5, 1, 4, 7, 1]|[3, 2, 8, 9, 4, 9]|[3, 2, 8, 9]|
# | Mike|[6, 9, 1, 8, 2]|   [1, 2, 3, 5, 8]|      [3, 5]|
# +-----+---------------+------------------+------------+
